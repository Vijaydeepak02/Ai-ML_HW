# %%
##Write a program that checks whether a number is positive, negative, or zero using if-else conditions. Test it with multiple sample inputs.##

# %%
number = float(input("Enter a number: "))

if number > 0:
    print("The number is positive.")
elif number < 0:
    print("The number is negative.")
else:
    print("The number is zero.")
# Out:
# Enter a number:  10
# The number is positive.

# %%
##Take five numbers as input and use a loop to determine whether each number is even or odd. Create a separate function for the logic.##

# %%
def check_even_odd(number):
    if number % 2 == 0:
        return "Even"
    else:
        return "Odd"

for i in range(5):
    number = int(input("Enter a number: "))
    
    result = check_even_odd(number)
    print(number, "is", result)
# Out:
# Enter a number:  10
# 10 is Even
# Enter a number:  12
# 12 is Even
# Enter a number:  15
# 15 is Odd
# Enter a number:  25
# 25 is Odd
# Enter a number:  14
# 14 is Even

# %%
##Build a menu-based calculator that performs addition, subtraction, multiplication, and division. Handle invalid input properly.##

# %%
print("1. Addition")
print("2. Subtraction")
print("3. Multiplication")
print("4. Division")

choice = input("Enter your choice: ")

num1 = float(input("Enter first number: "))
num2 = float(input("Enter second number: "))

if choice == "1":
    print("Result:", num1 + num2)

elif choice == "2":
    print("Result:", num1 - num2)

elif choice == "3":
    print("Result:", num1 * num2)

elif choice == "4":
    if num2 == 0:
        print("Cannot divide by zero")
    else:
        print("Result:", num1 / num2)

else:
    print("Invalid choice")
# Out:
# 1. Addition
# 2. Subtraction
# 3. Multiplication
# 4. Division
# Enter your choice:  2
# Enter first number:  5
# Enter second number:  4
# Result: 1.0

# %%
##Create a list and practice append, insert, remove, sort, and reverse operations. Print the result after each operation.##

# %%
numbers = [5, 2, 8, 1, 3]
print(numbers)

numbers.append(10)
print(numbers)

numbers.insert(2, 7)
print(numbers)

numbers.remove(2)
print(numbers)

numbers.sort()
print(numbers)

numbers.reverse()
print(numbers)
# Out:
# [5, 2, 8, 1, 3]
# [5, 2, 8, 1, 3, 10]
# [5, 2, 7, 8, 1, 3, 10]
# [5, 7, 8, 1, 3, 10]
# [1, 3, 5, 7, 8, 10]
# [10, 8, 7, 5, 3, 1]

# %%
##Find the maximum and minimum values in a list manually using loops instead of built-in functions.##

# %%
numbers = [10, 5, 25, 3, 15]

maximum = numbers[0]
minimum = numbers[0]

for number in numbers:
    if number > maximum:
        maximum = number

    if number < minimum:
        minimum = number

print("Maximum:", maximum)
print("Minimum:", minimum)
# Out:
# Maximum: 25
# Minimum: 3

# %%
##Calculate the sum and average of numbers in a list. Use functions to keep the code organized.##

# %%
numbers = [10, 20, 30, 40, 50]

def find_sum(numbers):
    return sum(numbers)

def find_average(numbers):
    return find_sum(numbers) / len(numbers)

print("Sum:", find_sum(numbers))
print("Average:", find_average(numbers))
# Out:
# Sum: 150
# Average: 30.0

# %%
##Generate a multiplication table from 1 to 10 for a given number using loops.##

# %%
number = int(input("Enter a number: "))

for i in range(1, 11):
    print(number, "x", i, "=", number * i)
# Out:
# Enter a number:  5
# 5 x 1 = 5
# 5 x 2 = 10
# 5 x 3 = 15
# 5 x 4 = 20
# 5 x 5 = 25
# 5 x 6 = 30
# 5 x 7 = 35
# 5 x 8 = 40
# 5 x 9 = 45
# 5 x 10 = 50
